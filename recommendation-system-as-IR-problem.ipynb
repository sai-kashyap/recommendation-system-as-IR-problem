# %%
from gensim.models.doc2vec import Doc2Vec, TaggedDocument

import numpy as np
import faiss
# Step 1: Data Preprocessing
# Function to process each line and extract the relevant information
def process_line(line):
    parts = line.strip().split('\t')
    user_id = parts[0]
    track_name = parts[5]
    return user_id, track_name

# Load the data and process each line
user_track_dict = {}
with open(r'C:\Users\saica\Downloads\lastfm-dataset-1K\lastfm-dataset-1K\userid-timestamp-artid-artname-traid-traname.tsv', 'r', encoding='utf-8') as file:
    for line in file:
        user_id, track_name = process_line(line)
        if user_id not in user_track_dict:
            user_track_dict[user_id] = []
        user_track_dict[user_id].append(track_name)

users=list(user_track_dict.keys())

# Convert user_track_dict to a list of user documents
user_docs = list(user_track_dict.values())

# %%
# Step 2: Doc2Vec Embedding
tagged_data = [TaggedDocument(words=doc, tags=[str(i)]) for i, doc in enumerate(user_docs)]

max_epochs = 200
vec_size = 54
alpha = 0.025
workers = -1  # Utilize all CPU cores
model = Doc2Vec(vector_size=vec_size, alpha=alpha, min_alpha=0.00025, min_count=1, dm=1, workers=workers)
model.build_vocab(tagged_data)
for epoch in range(max_epochs):
    model.train(tagged_data, total_examples=model.corpus_count, epochs=model.epochs)
    model.alpha -= 0.0002
    model.min_alpha = model.alpha
num_docs = len(user_docs)

# %%
all_embeddings=[]
for i in range(992):
    all_embeddings.append(model.dv[str(i)])
print(all_embeddings[0:5])
userkeys=list(user_track_dict.keys())
print(userkeys[0:5])

# Initialize an empty dictionary
user_embeddings_dict = {}

# Create the dictionary
for i, user_key in enumerate(userkeys):
    user_embeddings_dict[user_key] = all_embeddings[i]
# Out:
# [array([-0.0096867 , -0.01107246, -0.01829769,  0.0158386 ,  0.00660392,
#         0.0004871 , -0.01829746, -0.00956787, -0.01799623,  0.00372367,
#         0.00524132,  0.00859918, -0.00795792, -0.00582538, -0.00570146,
#        -0.01615169,  0.00402312,  0.01708449, -0.01759605, -0.00640386,
#        -0.00698131,  0.00482849, -0.01053992,  0.00485311,  0.01074541,
#        -0.0150127 , -0.01542554, -0.01843457,  0.00913527, -0.01689316,
#         0.01081845,  0.01259308, -0.01204889, -0.00837015, -0.00232382,
#         0.00304874, -0.00274322, -0.01581952, -0.00667151,  0.00320671,
#        -0.00380911, -0.01338897,  0.00774926, -0.01587841,  0.00502136,
#        -0.00854393,  0.00119524, -0.0038099 ,  0.0100245 , -0.01481958,
#        -0.00392565, -0.00017744, -0.01229403, -0.01208549], dtype=float32), array([-0.00357955,  0.01630273, -0.0023392 ,  0.00654811, -0.01064873,
#         0.01632373,  0.00539902,  0.0171846 ,  0.00805529, -0.00777698,
#         0.00415168, -0.00817121,  0.01069804,  0.00339171, -0.00421993,
#        -0.01089096, -0.01486497, -0.00157976, -0.01655438, -0.0170808 ,
#        -0.01470354,  0.0040168 , -0.01203878, -0.01442286,  0.00394661,
#         0.00380123,  0.01545992,  0.00864429, -0.01742612, -0.00062737,
#         0.0145445 ,  0.00494718,  0.00496364, -0.00904391,  0.01197624,
#         0.00305336, -0.01407805,  0.01271106, -0.01809148, -0.01510851,
#        -0.00902623,  0.01840311,  0.00576499, -0.00372599,  0.01647254,
#         0.00435418, -0.01029698, -0.00588988, -0.01105714,  0.00692905,
#        -0.01263748, -0.00372367, -0.0021011 ,  0.01352242], dtype=float32), array([ 0.01235976,  0.00632632, -0.00021119, -0.00868595, -0.00365657,
#        -0.00999501,  0.01647854, -0.01589847, -0.01846891, -0.00142272,
#         0.00677624,  0.01499384,  0.01647739,  0.01156818, -0.01155252,
#         0.01604673, -0.0174612 ,  0.00131343, -0.01226527, -0.0014815 ,
#         0.00488993, -0.01424797,  0.00733123,  0.00264367, -0.00099463,
#         0.01151561, -0.00810742, -0.00309856,  0.00190849,  0.00538144,
#        -0.0161831 , -0.00942646,  0.01458401,  0.00170512,  0.00685472,
#        -0.01727265, -0.00363629,  0.0040277 ,  0.0047657 ,  0.01650683,
#         0.00055454, -0.00871925, -0.00608482,  0.01781678,  0.01383768,
#        -0.01645677, -0.00666785,  0.0100739 ,  0.00164312,  0.01622488,
#        -0.0108616 , -0.00572595,  0.01555348,  0.01009188], dtype=float32), array([ 0.01616398, -0.00584223,  0.00427935, -0.01269156, -0.01098765,
#        -0.01095333, -0.01542124, -0.00409432,  0.00656577, -0.00302323,
#         0.00554227,  0.00940904,  0.01380418,  0.00470692,  0.01465582,
#        -0.00737838, -0.00884804, -0.00217261,  0.01089469,  0.0087891 ,
#        -0.01535229, -0.00543949, -0.01489777,  0.01614411, -0.00367967,
#        -0.00016743,  0.01595141,  0.00336132, -0.01375632,  0.01252347,
#         0.00872481,  0.01468892, -0.0072359 ,  0.00816453,  0.00899539,
#        -0.0075243 ,  0.00398572,  0.00985392, -0.01458258, -0.01704518,
#         0.01558198, -0.00803717,  0.01795543, -0.00492782,  0.01779924,
#        -0.01107425,  0.00618452,  0.00818679, -0.01607007,  0.00965467,
#        -0.01221324, -0.0068795 ,  0.008445  ,  0.01761561], dtype=float32), array([-0.00521281, -0.00568466,  0.00046712, -0.00106812, -0.01803633,
#        -0.01462761,  0.01068983,  0.01329196, -0.00861558,  0.00609214,
#        -0.00231359,  0.00648102, -0.01150385,  0.00532016, -0.00911606,
#        -0.0121951 ,  0.01577887, -0.01453211, -0.00552077,  0.00813905,
#        -0.01555284, -0.00880734,  0.00157721, -0.01082941,  0.01640619,
#         0.01668245,  0.01375101,  0.00523675, -0.00927591, -0.00091325,
#        -0.00370002,  0.01141013, -0.01289423, -0.01609418, -0.01793161,
#        -0.01484127, -0.01190826, -0.00427774, -0.00434831,  0.01163919,
#         0.00836197,  0.00961609,  0.00486787,  0.00376668,  0.00848077,
#         0.0162319 ,  0.00986977,  0.00378762, -0.00383272,  0.00961651,
#         0.0134097 ,  0.0171003 ,  0.01206036,  0.00860823], dtype=float32)]
# ['user_000001', 'user_000002', 'user_000003', 'user_000004', 'user_000005']

# %%
import faiss

# Convert embeddings to numpy array
doc_vectors = np.array([model.dv[str(i)] for i in range(num_docs - 5)])  # Remove the last 5 vectors

# Initialize a Faiss index
index = faiss.IndexFlatL2(vec_size)  # Assuming vec_size is the dimension of the embeddings

# Add document vectors to the index
index.add(doc_vectors)

# %%
import faiss

# Convert the embeddings of the left-out documents to numpy array
#   0.00870211 0.00870648 0.00871672 0.00872919 0.00874973 0.00875981
#   0.00879499 0.00883275 0.00883604 0.00889814]
#  [0.00582769 0.00632534 0.00659578 0.00661905 0.00662934 0.00668796
#   0.00691553 0.00695881 0.00709375 0.00711604 0.00714704 0.00738801
#   0.00739438 0.0074179  0.00743824 0.00744483 0.00756174 0.00757684
#   0.00759954 0.00764448 0.00767841 0.00779163 0.00781801 0.00783453
#   0.0078459  0.00789963 0.00790574 0.00802438 0.00803975 0.0080726
#   0.00812474 0.00814946 0.00815978 0.0081654  0.00816906 0.00821804
#   0.00824669 0.00825046 0.0082587  0.00827495]]

# %%
# Get the indices of the most similar vectors
similar_indices_last = I[-1]  # Last array of indices

# Convert indices to user keys in the format user_000xxx
similar_user_keys_last1 = [f"user_{idx:06d}" for idx in similar_indices_last]

print("Most similar user keys (last array):")
print(similar_user_keys_last1)
# Out:
# Most similar user keys (last array):
# ['user_000876', 'user_000185', 'user_000787', 'user_000482', 'user_000232', 'user_000385', 'user_000839', 'user_000874', 'user_000685', 'user_000240', 'user_000650', 'user_000703', 'user_000526', 'user_000498', 'user_000112', 'user_000086', 'user_000696', 'user_000721', 'user_000192', 'user_000022', 'user_000426', 'user_000722', 'user_000316', 'user_000038', 'user_000013', 'user_000849', 'user_000048', 'user_000690', 'user_000831', 'user_000634', 'user_000602', 'user_000339', 'user_000727', 'user_000639', 'user_000978', 'user_000082', 'user_000310', 'user_000052', 'user_000926', 'user_000515']

# %%
# Get the indices of the most similar vectors
similar_indices_last = I[-1]  # Last array of indices

# Convert indices to user keys in the format user_000xxx incremented by 1
similar_user_keys_last = [f"user_{idx + 1:06d}" for idx in similar_indices_last]
similar_indices_last=similar_user_keys_last + similar_user_keys_last1

print("Most similar user keys (last array):")
print(similar_user_keys_last)
# Out:
# Most similar user keys (last array):
# ['user_000877', 'user_000186', 'user_000788', 'user_000483', 'user_000233', 'user_000386', 'user_000840', 'user_000875', 'user_000686', 'user_000241', 'user_000651', 'user_000704', 'user_000527', 'user_000499', 'user_000113', 'user_000087', 'user_000697', 'user_000722', 'user_000193', 'user_000023', 'user_000427', 'user_000723', 'user_000317', 'user_000039', 'user_000014', 'user_000850', 'user_000049', 'user_000691', 'user_000832', 'user_000635', 'user_000603', 'user_000340', 'user_000728', 'user_000640', 'user_000979', 'user_000083', 'user_000311', 'user_000053', 'user_000927', 'user_000516']

# %%
similar_user_tracks_all = [user_track_dict[key] for key in similar_user_keys_last]

# Flatten the list of lists into a single list and convert it to a set
all_tracks_set = set(track for tracks_list in similar_user_tracks_all for track in tracks_list)

# %%
# Extract values from user_track_dict for the key 'user_000992' and convert to set
user_000992_tracks_set = set(user_track_dict['user_001000'])

print("Set of tracks for user_000992:")
print(user_000992_tracks_set)
print('Motherzone' in user_000992_tracks_set)
# Out:
# Set of tracks for user_000992:
# {"Don'T Stop", 'Miasto Doznań', 'Reckoner Live @ Gorge', 'Come As You Are', 'Blue Turning Gray', 'Sixteen, Maybe Less', 'Plasticities', 'The Trees Were Mistaken', 'Moonlight', "Heaven'S Demon", 'Thelonius', 'Simple Twist Of Fate', 'The Game (Feat. Dj Premier)', 'Tower Of Babel', 'Neony', 'Sic Of Elephants (Outtake)', 'The Rain', 'Make Like Paper', 'Vultures', 'Shot In The Dark', "You Wouldn'T Like Me", 'Ten-Day Interval', 'Farewell Ride', 'Mule', 'Say Aha', 'Galang Featuring Lil Vicious', 'Duet For Guitars #2', 'Different Rhythms Different People', 'Tom Courtenay', 'S.K.J.', 'Aviateur', 'Breathe Me', 'Street Justice', "Lion'S Mane", 'Silence', 'Time Of Action (Not Panic (A Better Way (Logarhythmix)))', 'John Lee Huber', 'Over My Head', 'A Wolf At The Door', 'Graves', 'Boom', 'Cold War', 'Caramel', 'Joe Dimaggio Done It Again', 'String Strikes', 'Black Republicans (Feat. Juelz Santana)', 'A Party (For Everyone (Get Involved (Logarhythmix)))', 'The Return Of Elsa Gillis', 'Pigs', 'Different', 'Reckoner Lockdown (Dj Earworm Remix)', 'Burn Your Life Down', 'Breakbeats', 'Know It All', 'Castle And Cathedral', 'Mílanó', 'Conversation Heart', 'Fortunate Fool', 'President Of What?', 'Living Message', 'Ella', 'Song For Myla Goldberg', 'The First Five Times', 'Vessels', 'The Questions', 'Traffic In The Sky', 'Soul Clap [Prd. Jake One]', 'Just For The Love', 'Nantes', 'Making Days Longer', 'Lies', 'The Desert Is On Fire', 'Complete Shakeup', 'The Moon', 'Down The River Of Golden Dreams', 'Good Life (Feat. T-Pain)', "Life Ain'T What It Seems", 'Why Do You Let Me Stay Here?', 'Lady', 'Cindy', "I'M An Adler Girl", 'If You See Me', 'I Missed The Glance', 'Self-Torture', 'Whyled Out! (Bulljun Remix)', 'Blues For Uncle Gibb', 'All Hands Against His Own', 'Smithereens (Stop Cryin)', 'Helicopter', 'Building Tension In 2 Dimensions', 'A Rush Of Blood To The Head', 'Cinder And Smoke', 'Northern Sky', 'Insert B (The Real Deal) / Nobody Knows', 'A Loverless Bed (W/Out Remission)', 'Half Asleep', 'Chicago (Acoustic Version)', 'She Passed Through', 'Autumn In New York', 'White Center', 'To Go Home', 'Thinking Loudly', 'Busby Berkeley Dreams', 'Another Saturday', 'Moving Pictures Silent Films', "Here'S That Song You Wanted", '“The Perfect Plan” (Produced By Best Kept Secret)', "What'S The Use?", 'Baby-T', 'Bazooka Tooth', "Cut It Loose Feat. Aaron Phiri Of Hearin' Aid", 'Tell Me What To Swallow', "That Which Wasn'T Said", 'Spare-Ohs', 'Climbing Up The Walls (Feat. Sneaker Pimps) (Zero 7 Remix)', 'Skip Town', '3 Plus 4', 'Knife', 'Shadows', 'Act Nice And Gentle', 'Pressure (Feat. Jay-Z)', 'Free Until They Cut Me Down', '39 Thieves', 'One By One', 'Fake Plastic Trees', 'Bring Back My Heart', 'Tunneling Through The Guy', 'Beyond', 'The Crooked Spine', 'Jay-Z (Feat. Lil Wayne) Vs Xiu Xiu - I Do Brooklyn When I Want', 'Fitz And The Dizzyspells', 'Mic Stance', 'Falling Like A Comet From The Sky', 'My', 'Baby', 'Bullet Proof', 'Like Spinning Plates', 'Old School Cylons', 'Love And Caring', '
ete Shakeup', 'The Lime Tree', 'Da Realist', 'Cold Knees (In April)', 'Less Yesterday, More Today', "Life Ain'T What It Seems", "World'S Greatest Concertos", 'The Ghost Of Old Bull Lee', 'M & L Rock (And C (Logarhythmi', '80S Problems (Tha Basix Vs. Mahjongg)', 'Górny Taras', 'Stomp (Young Buck, T.I. & Ludacris)', "I'M An Adler Girl", 'Heaven Bound And Glory Be', 'Whyled Out! (Bulljun Remix)', 'Case In Point', 'Cranes And Cranes And Cranes And Cranes', 'The Arctic Circle', 'Hold On Love', 'She Passed Through', 'One Two (Shit On The Industry (Logarhythmix))', 'Teknopathetic', 'To Go Home', 'Thinking Loudly', 'Pieholden Suite (Feat. Andrew Bird And The Total Pros)', 'Flood, Part 1', 'Glamour And Glitz', 'Not A Robot, But A Ghost', 'Moving Pictures Silent Films', 'Echolocation', "Here'S That Song You Wanted", '“The Perfect Plan” (Produced By Best Kept Secret)', 'Baby-T', 'Bokfresh', "Hustlin' Daze (Feat. Donell Jones)", 'Untitled Track 9', "Cut It Loose Feat. Aaron Phiri Of Hearin' Aid", 'Soldiers Crash Gathering In Sparrow Hills', 'Champion (Nick Catchdubs Remix)', 'Repeat Defender', 'D.O.G.', 'Connie', 'Eye Know- Feat The Macpodz-Cms', 'Climbing Up The Walls (Feat. Sneaker Pimps) (Zero 7 Remix)', '3 Plus 4', 'Lorge', 'Play Your Part, Part 2', "Don'T Thank Me", 'Too Happy For Qwel', "I'M Onto Something (That'S What She Said)", 'Detergen', 'My Only Swerving', 'Najważniejszy Dzień', 'My Favorite Letter', 'Pressure (Feat. Jay-Z)', '39 Thieves', '“The Grown Up” (Produced By Best Kept Secret)', 'Csámborgó', 'Rag For Madi', 'Bring Back My Heart', 'Hot Air Balloon', 'The Crooked Spine', "Cock O' The Walk", 'B-Boy Code Pt. 2', 'Never Scared', 'Your Love Iz What It Iz (The Cool Kids Vs. Frankie Knuckles)', 'Jay-Z (Feat. Lil Wayne) Vs Xiu Xiu - I Do Brooklyn When I Want', 'Fitz And The Dizzyspells', 'The Next Train', 'Falling Like A Comet From The Sky', 'Back In Your Own Back Yard', 'Stallion', 'I Am Part Of A Large Family', '21 Dni', 'Out Of Here', 'Got This Rage', 'To Renew, Cause To Grow, Or Bloom Again', 'Krótka Piosenka O Miłości', 'Future Dads (Platinum Edition)', 'Barry Bonds (Eli Escobar Remix)', 'Old School Cylons', 'Ghost 3 (Yurei)', 'Nightfall (For Boris P)', 'All That Talking', 'Put There By The Land', 'Baby Pop', 'Flambee Montalbanese', 'Samurai Mania', 'Angel Pumping Gas', 'One Sexy Summer Night', 'Peanut Butter Fairy', "Maestro'S Rocketship", 'Rojiura No Usagi', 'Rotten Hell', 'The Boy ...

# %%
print(1-len(unique_tracks_user_000992)/len(user_000992_tracks_set))
# Out:
# 0.7083415112855741

# %%
# Get the indices of the most similar vectors
similar_indices_last = I[-1]  # Last array of indices

# Convert indices to user keys in the format user_000xxx incremented by 1
similar_user_keys_last = [f"user_{idx + 1:06d}" for idx in similar_indices_last]
similar_indices_last=similar_user_keys_last + similar_user_keys_last1

print("Most similar user keys (last array):")
print(similar_user_keys_last)

similar_user_tracks_all = [user_track_dict[key] for key in similar_user_keys_last]

# Flatten the list of lists into a single list and convert it to a set
all_tracks_set = set(track for tracks_list in similar_user_tracks_all for track in tracks_list)

# Extract values from user_track_dict for the key 'user_000992' and convert to set
user_001000_tracks_set = set(user_track_dict['user_001000'])

print("Set of tracks for user_001000:")
print(user_001000_tracks_set)

# Find elements present in user_000992_tracks_set but not in all_tracks_set
unique_tracks_user_000991 = user_001000_tracks_set - all_tracks_set

print("Unique tracks in user_000992_tracks_set:")
print(unique_tracks_user_000991)


print(1-len(unique_tracks_user_000991)/len(user_001000_tracks_set))
# Out:
# Most similar user keys (last array):
# ['user_000877', 'user_000186', 'user_000788', 'user_000483', 'user_000233', 'user_000386', 'user_000840', 'user_000875', 'user_000686', 'user_000241', 'user_000651', 'user_000704', 'user_000527', 'user_000499', 'user_000113', 'user_000087', 'user_000697', 'user_000722', 'user_000193', 'user_000023', 'user_000427', 'user_000723', 'user_000317', 'user_000039', 'user_000014', 'user_000850', 'user_000049', 'user_000691', 'user_000832', 'user_000635', 'user_000603', 'user_000340', 'user_000728', 'user_000640', 'user_000979', 'user_000083', 'user_000311', 'user_000053', 'user_000927', 'user_000516']
# Set of tracks for user_001000:
# {"Don'T Stop", 'Miasto Doznań', 'Reckoner Live @ Gorge', 'Come As You Are', 'Blue Turning Gray', 'Sixteen, Maybe Less', 'Plasticities', 'The Trees Were Mistaken', 'Moonlight', "Heaven'S Demon", 'Thelonius', 'Simple Twist Of Fate', 'The Game (Feat. Dj Premier)', 'Tower Of Babel', 'Neony', 'Sic Of Elephants (Outtake)', 'The Rain', 'Make Like Paper', 'Vultures', 'Shot In The Dark', "You Wouldn'T Like Me", 'Ten-Day Interval', 'Farewell Ride', 'Mule', 'Say Aha', 'Galang Featuring Lil Vicious', 'Duet For Guitars #2', 'Different Rhythms Different People', 'Tom Courtenay', 'S.K.J.', 'Aviateur', 'Breathe Me', 'Street Justice', "Lion'S Mane", 'Silence', 'Time Of Action (Not Panic (A Better Way (Logarhythmix)))', 'John Lee Huber', 'Over My Head', 'A Wolf At The Door', 'Graves', 'Boom', 'Cold War', 'Caramel', 'Joe Dimaggio Done It Again', 'String Strikes', 'Black Republicans (Feat. Juelz Santana)', 'A Party (For Everyone (Get Involved (Logarhythmix)))', 'The Return Of Elsa Gillis', 'Pigs', 'Different', 'Reckoner Lockdown (Dj Earworm Remix)', 'Burn Your Life Down', 'Breakbeats', 'Know It All', 'Castle And Cathedral', 'Mílanó', 'Conversation Heart', 'Fortunate Fool', 'President Of What?', 'Living Message', 'Ella', 'Song For Myla Goldberg', 'The First Five Times', 'Vessels', 'The Questions', 'Traffic In The Sky', 'Soul Clap [Prd. Jake One]', 'Just For The Love', 'Nantes', 'Making Days Longer', 'Lies', 'The Desert Is On Fire', 'Complete Shakeup', 'The Moon', 'Down The River Of Golden Dreams', 'Good Life (Feat. T-Pain)', "Life Ain'T What It Seems", 'Why Do You Let Me Stay Here?', 'Lady', 'Cindy', "I'M An Adler Girl", 'If You See
walk", 'B-Boy Code Pt. 2', 'Never Scared', 'Your Love Iz What It Iz (The Cool Kids Vs. Frankie Knuckles)', 'Jay-Z (Feat. Lil Wayne) Vs Xiu Xiu - I Do Brooklyn When I Want', 'Fitz And The Dizzyspells', 'The Next Train', 'Falling Like A Comet From The Sky', 'Back In Your Own Back Yard', 'Stallion', 'I Am Part Of A Large Family', '21 Dni', 'Out Of Here', 'Got This Rage', 'To Renew, Cause To Grow, Or Bloom Again', 'Krótka Piosenka O Miłości', 'Future Dads (Platinum Edition)', 'Barry Bonds (Eli Escobar Remix)', 'Old School Cylons', 'Ghost 3 (Yurei)', 'Nightfall (For Boris P)', 'All That Talking', 'Put There By The Land', 'Baby Pop', 'Flambee Montalbanese', 'Samurai Mania', 'Angel Pumping Gas', 'One Sexy Summer Night', 'Peanut Butter Fairy', "Maestro'S Rocketship", 'Rojiura No Usagi', 'Rotten Hell', 'The Boy ...
# 0.7083415112855741

# %%
# Get the indices of the most similar vectors
similar_indices_last = I[-1]  # Last array of indices

# Convert indices to user keys in the format user_000xxx incremented by 1
similar_user_keys_last = [f"user_{idx + 1:06d}" for idx in similar_indices_last]
similar_indices_last=similar_user_keys_last + similar_user_keys_last1

print("Most similar user keys (last array):")
print(similar_user_keys_last)

similar_user_tracks_all = [user_track_dict[key] for key in similar_user_keys_last]

# Flatten the list of lists into a single list and convert it to a set
all_tracks_set = set(track for tracks_list in similar_user_tracks_all for track in tracks_list)

# Extract values from user_track_dict for the key 'user_000992' and convert to set
user_001000_tracks_set = set(user_track_dict['user_001000'])

print("Set of tracks for user_001000:")
print(user_001000_tracks_set)

# Find elements present in user_000992_tracks_set but not in all_tracks_set
unique_tracks_user_000991 = user_001000_tracks_set - all_tracks_set

print("Unique tracks in user_000992_tracks_set:")
print(unique_tracks_user_000991)


print(1-len(unique_tracks_user_000991)/len(user_001000_tracks_set))
# Out:
# Most similar user keys (last array):
# ['user_000877', 'user_000186', 'user_000788', 'user_000483', 'user_000233', 'user_000386', 'user_000840', 'user_000875', 'user_000686', 'user_000241', 'user_000651', 'user_000704', 'user_000527', 'user_000499', 'user_000113', 'user_000087', 'user_000697', 'user_000722', 'user_000193', 'user_000023', 'user_000427', 'user_000723', 'user_000317', 'user_000039', 'user_000014', 'user_000850', 'user_000049', 'user_000691', 'user_000832', 'user_000635', 'user_000603', 'user_000340', 'user_000728', 'user_000640', 'user_000979', 'user_000083', 'user_000311', 'user_000053', 'user_000927', 'user_000516']
# Set of tracks for user_001000:
# {"Don'T Stop", 'Miasto Doznań', 'Reckoner Live @ Gorge', 'Come As You Are', 'Blue Turning Gray', 'Sixteen, Maybe Less', 'Plasticities', 'The Trees Were Mistaken', 'Moonlight', "Heaven'S Demon", 'Thelonius', 'Simple Twist Of Fate', 'The Game (Feat. Dj Premier)', 'Tower Of Babel', 'Neony', 'Sic Of Elephants (Outtake)', 'The Rain', 'Make Like Paper', 'Vultures', 'Shot In The Dark', "You Wouldn'T Like Me", 'Ten-Day Interval', 'Farewell Ride', 'Mule', 'Say Aha', 'Galang Featuring Lil Vicious', 'Duet
Industry (Logarhythmix))', 'Teknopathetic', 'To Go Home', 'Thinking Loudly', 'Pieholden Suite (Feat. Andrew Bird And The Total Pros)', 'Flood, Part 1', 'Glamour And Glitz', 'Not A Robot, But A Ghost', 'Moving Pictures Silent Films', 'Echolocation', "Here'S That Song You Wanted", '“The Perfect Plan” (Produced By Best Kept Secret)', 'Baby-T', 'Bokfresh', "Hustlin' Daze (Feat. Donell Jones)", 'Untitled Track 9', "Cut It Loose Feat. Aaron Phiri Of Hearin' Aid", 'Soldiers Crash Gathering In Sparrow Hills', 'Champion (Nick Catchdubs Remix)', 'Repeat Defender', 'D.O.G.', 'Connie', 'Eye Know- Feat The Macpodz-Cms', 'Climbing Up The Walls (Feat. Sneaker Pimps) (Zero 7 Remix)', '3 Plus 4', 'Lorge', 'Play Your Part, Part 2', "Don'T Thank Me", 'Too Happy For Qwel', "I'M Onto Something (That'S What She Said)", 'Detergen', 'My Only Swerving', 'Najważniejszy Dzień', 'My Favorite Letter', 'Pressure (Feat. Jay-Z)', '39 Thieves', '“The Grown Up” (Produced By Best Kept Secret)', 'Csámborgó', 'Rag For Madi', 'Bring Back My Heart', 'Hot Air Balloon', 'The Crooked Spine', "Cock O' The Walk", 'B-Boy Code Pt. 2', 'Never Scared', 'Your Love Iz What It Iz (The Cool Kids Vs. Frankie Knuckles)', 'Jay-Z (Feat. Lil Wayne) Vs Xiu Xiu - I Do Brooklyn When I Want', 'Fitz And The Dizzyspells', 'The Next Train', 'Falling Like A Comet From The Sky', 'Back In Your Own Back Yard', 'Stallion', 'I Am Part Of A Large Family', '21 Dni', 'Out Of Here', 'Got This Rage', 'To Renew, Cause To Grow, Or Bloom Again', 'Krótka Piosenka O Miłości', 'Future Dads (Platinum Edition)', 'Barry Bonds (Eli Escobar Remix)', 'Old School Cylons', 'Ghost 3 (Yurei)', 'Nightfall (For Boris P)', 'All That Talking', 'Put There By The Land', 'Baby Pop', 'Flambee Montalbanese', 'Samurai Mania', 'Angel Pumping Gas', 'One Sexy Summer Night', 'Peanut Butter Fairy', "Maestro'S Rocketship", 'Rojiura No Usagi', 'Rotten Hell', 'The Boy ...
# 0.7083415112855741

# %%
# Get the indices of the most similar vectors
similar_indices_last = I[-2]  # Last array of indices

# Convert indices to user keys in the format user_000xxx incremented by 1
similar_user_keys_last = [f"user_{idx + 1:06d}" for idx in similar_indices_last]
similar_indices_last=similar_user_keys_last + similar_user_keys_last1

print("Most similar user keys (last array):")
print(similar_user_keys_last)

similar_user_tracks_all = [user_track_dict[key] for key in similar_user_keys_last]

# Flatten the list of lists into a single list and convert it to a set
all_tracks_set = set(track for tracks_list in similar_user_tracks_all for track in tracks_list)

# Extract values from user_track_dict for the key 'user_000992' and convert to set
user_001000_tracks_set = set(user_track_dict['user_000999'])

print("Set of tracks for user_001000:")
print(user_001000_tracks_set)

# Find elements present in user_000992_tracks_set but not in all_tracks_set
unique_tracks_user_000991 = user_001000_tracks_set - all_tracks_set

print("Unique tracks in user_000992_tracks_set:")
print(unique_tracks_user_000991)


print(1-len(unique_tracks_user_000991)/len(user_001000_tracks_set))
# Out:
# Most similar user keys (last array):
# ['user_000601', 'user_000846', 'user_000695', 'user_000284', 'user_000789', 'user_000126', 'user_000572', 'user_000722', 'user_000890', 'user_000934', 'user_000530', 'user_000648', 'user_000452', 'user_000133', 'user_000279', 'user_000542', 'user_000258', 'user_000870', 'user_000494', 'user_000142', 'user_000516', 'user_000715', 'user_000685', 'user_000590', 'user_000430', 'user_000036', 'user_000863', 'user_000245', 'user_000386', 'user_000226', 'user_000603', 'user_000976', 'user_000595', 'user_000597', 'user_000101', 'user_000709', 'user_000410', 'user_000312', 'user_000114', 'user_000429']
# Set of tracks for user_001000:
# {'Odejdę, Gdy Zapieje Kur', 'Under The Gun', 'Special K', 'House Of Wolves', 'Koi No Megalover', 'Digital Bath', 'Big Yellow Taxi', 'Leif Erikson', 'Kdyby', 'Wish', 'Miss Moneypenny', 'She Moves In Her Own Way', 'Working Class Hero (Amended Album Version)', 'Op. 48, No. 2 In F-Sharp Minor', 'Pink Shoelaces', 'Rhineland (Heartland)', 'All You Need Is Love', 'Life During Wartime', 'Killing The Light', 'Survivalism', 'Crazy In Love (Feat. Jay Z)', 'Sparks', 'Devotion And Desire', 'El Pico', 'Zrób Sobie Wolne', 'Yes This Is My Broken Shield', 'Gossip', 'Girl', "There'S No Solution", 'Lost For Words', 'Revenge', 'Nobody Home', 'Winter: The Beginning Of The End', 'Ddevil', "Baby, You Wouldn'T Last A Minute On The Creek", 'Charlotte', "Since I'Ve Been Loving You", 'Explosivo', 'Curious', 'Low', 'Vampires Will Never Hurt You', 'Armia Zbawienia', 'Girls, Be Ambitious', 'R U Still In 2 It', 'Alexander', 'Newport Living', 'That Time', 'Amore', 'Eli', 'Bite Your Rhymes', 'The Fallen Interlude', 'Keep Talking', '..............................', "Nobody'S Fault But Mine", 'Pins And Needles', 'Battle-Axe', 'March Of The Pigs (Lp Version)', 'Parachutes', 'If You', 'Complications Of The Flesh', 'Mon Légionnaire', 'Genesis', 'Oresama Shikou', 'Welcome To The Universe', 'Ya Mama', 'Starstrukk', 'Boom', 'Sanctified', 'Re-L124C41+', "Everybody'S Screaming!!!", 'Píseň O Příteli', 'Track02 27', 'Tight', 'Something Rotten', 'P5Hng Me A*Wy', 'Pigs', "Hitchin' A Ride", 'Hang On To Your Iq', 'World Outside', "Lover I Don'T Have To Love", 'Fabian Policy', 'Gimme More', 'Are You Ready To Rock? -Rhythm Battle Mix-', 'Ukolébavka', 'Good Luck A Marriage Dance', 'La Java De Cezigue', 'When The Levee Breaks', 'Mesečina / Moonlight', 'Lux Aeterna', 'Mílanó', 'This River Is Wild', 'Tabasko (Kochan & O.S.T.R. & Tomila) - Czas I Pieniądz (Bonus Track)', 'Nüguns', 'Fer Sure', 'Jeszcze, Jeszcze', 'Sweetest Perfection (Depeche Mode Cover)', 'Forest', 'Bananaphone', 'Přelezl Jsem Plot', 'Fire It Up', 'Por Que Te Vas', '19 - Limehouse Blues - °Cochlea°', 'Velká Voda', 'Nantes', 'I Came As A Rat', 'Banquet', 'Tropical Moonlight', 'X', 'Situations', 'The Salmon Dance (Feat. F
Sexfyra', 'You Talk A Good Game', 'Tropical Moonlight', 'Alkohol', 'The Salmon Dance (Feat. Fatlip)', 'Live In Tromba No. 4', 'Vital Signs', 'Heřmánkové Štěstí', 'Jpn Pride', 'Złodziej', 'Ja I Mój Lolo', '18 Ghosts Ii', 'Můj Pes', 'Dyskoteka Gra', 'Broadsword Calling Danny Boy', 'Secret Letters', 'Neon Golden', 'Jouzai', 'Tak Mija Czas', 'Gamebox', '30 Ghosts Iv', 'No. 15 In F-Minor, Op. 55/1', 'Kosatá A Zubatá', '01 - Minor Swing - °Cochlea°', 'Od Kiedy Ropą', 'Nocturne In G Minor, Op. 37, No. 1', 'The Chauffer', "Through The Roof 'N' Underground", "Babe, I'M On Fire", 'Leaving Hope', 'If I Was Your Vampire', 'Taka Historia', 'モーツァルト: 歌劇「コジ・ファン・トゥッテ」～「軍隊生活はすばらしい」', 'Who Let You Go?', 'Running Up That Hill (Live F ...
# 0.6101295641931684

# %%
# Get the indices of the most similar vectors
similar_indices_last = I[-3]  # Last array of indices

# Convert indices to user keys in the format user_000xxx incremented by 1
similar_user_keys_last = [f"user_{idx + 1:06d}" for idx in similar_indices_last]
similar_indices_last=similar_user_keys_last + similar_user_keys_last1

print("Most similar user keys (last array):")
print(similar_user_keys_last)

similar_user_tracks_all = [user_track_dict[key] for key in similar_user_keys_last]

# Flatten the list of lists into a single list and convert it to a set
all_tracks_set = set(track for tracks_list in similar_user_tracks_all for track in tracks_list)

# Extract values from user_track_dict for the key 'user_000992' and convert to set
user_001000_tracks_set = set(user_track_dict['user_000997'])

print("Set of tracks for user_001000:")
print(user_001000_tracks_set)

# Find elements present in user_000992_tracks_set but not in all_tracks_set
unique_tracks_user_000991 = user_001000_tracks_set - all_tracks_set

print("Unique tracks in user_000992_tracks_set:")
print(unique_tracks_user_000991)


print(1-len(unique_tracks_user_000991)/len(user_001000_tracks_set))
# Out:
# Most similar user keys (last array):
# ['user_000408', 'user_000193', 'user_000474', 'user_000484', 'user_000119', 'user_000357', 'user_000396', 'user_000179', 'user_000425', 'user_000478', 'user_000343', 'user_000149', 'user_000900', 'user_000040', 'user_000698', 'user_000635', 'user_000644', 'user_000564', 'user_000851', 'user_000982', 'user_000083', 'user_000827', 'user_000483', 'user_000843', 'user_000766', 'user_000295', 'user_000941', 'user_000608', 'user_000788', 'user_000939', 'user_000386', 'user_000689', 'user_000231', 'user_000190', 'user_000573', 'user_000890', 'user_000616', 'user_000767', 'user_000624', 'user_000516']
# Set of tracks for user_001000:
# {'99 To Life', 'Dawna', 'Still In Love', 'Story Of My Life', 'Girl Anachronism', 'Incubus Succubus Ii', 'Edit', 'In The Flat Field', 'Blues From A Gun', 'Karate', "Let'S Get Def", 'Pleasure Is The Boss', 'Airwaves', 'Lust For Life', 'You Are Fading', 'Huh...What?', '1945', 'Wardance', 'From Suspicious Minds', 'Love The Virgins', 'The Model', 'Twenty Four Hours', 'I Got A Right', 'Hotel Song', 'Silver Waterfalls', "Bela Lugosi'S Dead", 'The Mermaid Song', 'Harry', 'Moped', "Tomorrow'S World", 'Me And Mr J
That Rainbow - Barbra Streisand", 'Birmingham', 'Big Drag', 'Blood Satisfaction', 'See My Wife', 'Heat It Up', 'I Know You, Part Ii', 'Fakes & Liars', 'Love Will Tear You Apart (She Wants Revenge Vs Bauhaus & Joy Division)', 'Question Of Time', 'Dig A Hole', 'Couch', 'Angel (Lp Version)', 'I Love My Soul', 'Let Your Good Heart Lead You Home', 'Crowded In The Wings', 'Slowtime', 'Fire Eater', 'Riders On The Heart', 'Generation Of Unity', 'Starblood', 'See You Tomorrow', 'Your Mama', 'For The Love Of Ivy', 'Falling Down (Die Braut Remix)', 'Dim Allentown Cove (Part I)', 'Sister Cry', 'The Deep Briny', 'Ballad Of Bodmin Pill', 'Two Angels', 'Secret Track (Ssshhh)', 'Straight Out Of Canton (Iron Wok Remix)', 'Derek The Confessor', 'The Bilbao Song', 'I Need More', 'Maybeline', 'Prayer Flags', 'Dim Sum Girl', 'Well, Did You Evah!', 'Misguided Angel', 'Got To Get Up', 'Hammer The Halo', 'Higher Wall', 'My Ship', 'I Will Be Grateful For This Day', 'Born In The 80S', 'Song And Dance', 'The Three Shadows, Part I', 'Moonchild (King Crimson Remix)', 'Street Of Chinatown', 'I Felt The Luxury', 'Kill City', 'Settled Down Like Rain', 'She\'S Lost Control (12" Version)', 'Fun And Games', 'Hong Kong Heartbreak', 'Jazzhole', 'Freak Train', 'The Charge', 'Biters Block', 'Mama Told Me Not To Come (7" Mix)', '11 Years', 'Spirit (Single Version)', 'A Brain In A Room', 'Watch Without Pain', "Trippin' On An Underground Space Age Reggae Movie At A Seaside Hovercraft Drive-In Near Stardance Galaxy", "Egg Rollin'", 'Mama Made Me A Pimp', 'Bd 3', "God'S Zoo", 'The Winds Of Change (So Many Things)', 'One Life To Live', 'Sucker (Young Mix)', 'Silly Thing', 'Transmission (Peel Session)', 'Going South (7" Version)', 'Computerwelt', "Here I'Ll Stay", 'Buddha Time', 'I Am The Crime', 'All You P ...
# 0.6679012345679012

# %%
# Get the indices of the most similar vectors
similar_indices_last = I[-4]  # Last array of indices

# Convert indices to user keys in the format user_000xxx incremented by 1
similar_user_keys_last = [f"user_{idx + 1:06d}" for idx in similar_indices_last]
similar_indices_last=similar_user_keys_last + similar_user_keys_last1

print("Most similar user keys (last array):")
print(similar_user_keys_last)

similar_user_tracks_all = [user_track_dict[key] for key in similar_user_keys_last]

# Flatten the list of lists into a single list and convert it to a set
all_tracks_set = set(track for tracks_list in similar_user_tracks_all for track in tracks_list)

# Extract values from user_track_dict for the key 'user_000992' and convert to set
user_000999_tracks_set = set(user_track_dict['user_000996'])

print("Set of tracks for user_000990:")
print(user_000999_tracks_set)

# Find elements present in user_000992_tracks_set but not in all_tracks_set
unique_tracks_user_000999 = user_000999_tracks_set - all_tracks_set

print("Unique tracks in user_000999_tracks_set:")
print(unique_tracks_user_000999)


print(1-len(unique_tracks_user_000999)/len(user_000999_tracks_set))
# Out:
# Most similar user keys (last array):
# ['user_000295', 'user_000417', 'user_000789', 'user_000503', 'user_000533', 'user_000839', 'user_000590', 'user_000930', 'user_000510', 'user_000845', 'user_000133', 'user_000263', 'user_000576', 'user_000734', 'user_000667', 'user_000777', 'user_000005', 'user_000572', 'user_000758', 'user_000426', 'user_000182', 'user_000504', 'user_000605', 'user_000353', 'user_000597', 'user_000204', 'user_000410', 'user_000328', 'user_000338', 'user_000276', 'user_000814', 'user_000321', 'user_000934', 'user_000644', 'user_000239', 'user_000841', 'user_000430', 'user_000031', 'user_000103', 'user_000754']
# Set of tracks for user_000990:
# {'Ghetto Youth', 'The Clock', 'In This World', 'Sail To The Moon', 'Counting Blue Cars', 'Street Spirit (Fade Out)', 'Walk The Line', 'Lump', 'Black Steel', 'Your Song', "Don'T Look Back In Anger", 'Nothing Left To Lose', 'Corpus Christi Carol', 'Karmacoma', 'Natural Blues', 'The Beautiful People', 'Girl', 'People Carrier', 'Length Of Love', 'Feel Good Inc. (Album Version)', 'Bullet With Butterfly Wings', 'Give It Away', 'Nobody', 'Asshole', 'Dance Me', 'Only You', 'Atoms For Peace', 'Morning Bell', 'Myxamatosis', 'Da Hoola (Soda-Pop Mix)', 'Mad About You', "Doin' Time (Uptown Dub)", 'The Passing Stars', 'Lovely Head', 'Unfinished Sympathy', 'Doll Parts', 'Life In Mono', 'Opener', 'Part Of The Process', 'All The Small Things', 'Protection (Feat. Tracey Thorn)', 'The Bends', 'Damn I Wish I Was Your Lover', 'Bullet Proof...I Wish I Was', 'Until The Morning', "L'Incertitude D'Heisenberg", 'Hemorrhage (In My Hands)', 'Losing My Religion', 'Your Song (Ewan Mcgregor)', "C'Mere", 'Love Can Damage Your Health', 'Hanging By A Moment', 'Excess', 'Cowboys', 'Ripcord', 'Makes Me Wanna Die', 'Go To Sleep', 'Skip Divided', 'Climbing Up The Walls  (Radioh', 'Where I End And You Begin', 'Light Blue Movers', 'Bad Things', 'Lebanese Blonde', 'I Might Be Wrong', 'Massive Attack - Safe From Harm', 'First Instant Last Report', 'Banquet', 'Forgive Them Father', '13 13 Radiohead - Black Star (Acoustic)', 'Wolf At The Door', 'Karma Coma', 'The Seed 2.0', '24 Hour Charleston', 'Lyrics Of Fury', 'A Time To Be So Small', 'Part Of The Queue', 'Message Personnel', 'Public Pervert', 'Ten Men', 'Sour Times', 'Smile', 'Honey', 'I Be The Prophet (With Drums)', 'Wonderwall (Acoustic)', 'Morning Sun', 'Daylight Robbery', "It'S Okay To Think About Ending", 'Half Day Closing', 'Fog', 'Caught By The River', 'Champagne Supernova', 'Colour Me', "Baba O'Remix", 'Subterranean Homesick Alien', 'What Your Soul Sings', 'Humming', 'Radiohead & Portishead - Blow Out', 'Glycerine', "The Word 'Hurricane'", 'So Real', 'Biscuit', 'The Eraser', 'Bullet Proof..I Wish I Was', 'Black Steel (Radio Edit)', 'Planet Telex', "Something'S Always Wrong", 'Ready To Go', 'Just', 'Treefingers', 'Black Swan', 'Undenied', 'Lighten Up', 'Radiohead - Coke Babies', 'Take A Picture', 'Smells Like Teen Spirit', 'Live With Me', 'How High', 'Seventeen Years', 'Angelica', 'Mezzanine', 'Hysteria', 'What Do I Have To Do?', 'Suffocated Love', 'Highschool Lover', 'Trishika', 'Over And Over', 'They', 'Far Behind', 'Who Can You Trust?', 'Kool Thing', 'Tricky Kid', 'Une Very Stylish Fille (Kenny Dope Mix)', 'Crawl', 'Fake Plastic Trees', 'Risingson (Underworld Mix)', 'All Mixed Up', 'Easy', 'Teardrop', 'Not Even Jail', 'Climbing Up The Walls', 'Banana Co', 'Rabbit In Your Headlights', 'Roads', 'Breathe', 'Girlfriend', 'I Wanna Feel The Chill', 'Transcendence', 'Nothing Even Matters', 'Acid Jazz And Trip Hop - Massi', 'And It Rained All Night', 'Just A Girl', "Brand New You'Re Retro", 'Feed Me', 'Sex Drive', 'Facts Are', 'Checkered Floor', 'Like Spinning Plates', 'Aftermath (Version 1)', 'Punchdrunk Lovesick Singalong', 'Trigger Hippie', 'Guitar Flute & String', 'Future Proof', 'Lonely Soul', 'Life In Mono (Propellerheads Sweat Band Mix)', 'Feel Good Inc.', 'Vent', 'Crazy In Love', 'Red Dust', 'Burn The Witch', 'Wash My Soul', 'The World I Know', 'In Winter Still', 'Exchange', 'Likufanele', 'Inertia Creeps', 'Sulk', 'Strict Machine', 'When It Hurts So Bad', 'New York', 'Idioteque', 'Evil', 'Mexicola', 'Next Exit', "Fallin'", 'Western Eyes', "Block Rockin' Beats", 'The Bends / Fake Plastic Trees', 'Analyse', 'Spinning', 'If You Could Only See', 'Pyramid Song', '6 Underground', 'Risingson', "Here'S To The Night", 'Give It Up', 'Christiansands', 'My Evil Is Strong', "Strugglin'", 'Antidote', 'Mysterons', 'Man Next Door', 'Paranoid Android', 'Grace', 'Salt Water Sound', 'Alpha Female', 'Moody', 'Last Flowers To The Hospital', 'Cherry', 'Sex And Candy', 'My Iron Lung', 'Love', 'Utopia', 'House Of The Rising Sun', ...
# Unique tracks in user_000999_tracks_set:
# {'Ghetto Youth', 'Alpha Female', 'Colour Me', 'Hours From My Life', 'As I Lay Me Down', 'Counting Blue Cars', 'Last Flowers To The Hospital', "Baba O'Remix", 'Walk The Line', 'Radiohead & Portishead - Blow Out', 'You Were Meant For Me', "Something'S Always Wrong", "C' Mere", 'Radiohead - Sunday Bloody Sunday (U2 Cover Live)', 'Radiohead - Coke Babies', 'Take A Picture', 'Desperately Wanting', 'B.O.B (Bombs Over Baghdad)', 'Asshole', 'Dance Me', 'Breathe (Extended Mix)', 'What Do I Have To Do?', 'Born Slippy .Nuxx (Short)', 'In A State (Sasha Remix)', 'Trishika', 'Dy-Na-Mi-Tee', 'Interactive Booklet - The Eraser', 'Teenage Wasteland', 'Radiohead - Big Ideas', 'Une Very Stylish Fille (Kenny Dope Mix)', 'The Passing Stars', "It'S Been Done", 'Risingson (Underworld Mix)', 'Lost Ones', 'Nobody Loves Me (Massive Attack Mix)', 'Opener', 'Protection (Feat. Tracey Thorn)', 'Radiohead - Coke Babies Copy', 'Banana Co', 'Everything You Want', 'Bullet Proof...I Wish I Was', "L'Incertitude D'Heisenberg", '13 13 13 13 13 13 Radiohead - Black Star (Acoustic)', 'Your Song (Ewan Mcgregor)', 'Nothing Even Matters', 'Depeche Mode - All I Ever Wanted', 'Acid Jazz And Trip Hop - Massi', 'Excess', 'Radiohead - Ladytron', 'Feed Me', 'Singing The Blues', 'Climbing Up The Walls  (Radioh', 'Scrappy Love', 'Checkered Floor', 'Aftermath (Version 1)', 'Edge Of The Ocean (Duotone Mix Edit)', "What It'S Like", 'I Want You Back (Single Version)', 'Broken Homes', 'Massive Attack - Safe From Harm', 'First Instant Last Report', '13 13 Radiohead - Black Star (Acoustic)', 'Forgive Them Father', 'Wolf At The Door', 'Alien Workshop', 'Life In Mono (Propellerheads Sweat Band Mix)', "I'M Like A Bird", 'Wash My Soul', 'To Zion', 'In Winter Still', 'The Freshmen', 'Velvet Divorce', "Let'S Go Again", 'Something In The Way She Moves (Beatles Cover)', 'When It Hurts So Bad', 'Lightning Crashes', 'I Be The Prophet (With Drums)', 'Wonderwall (Acoustic)', 'The Bends / Fake Plastic Trees', 'If You Could Only See', 'How I Made My Millions', 'Outkast - The Whole World(2)', 'Pumpkin (Edit)', "Here'S To The Night", "It'S Okay To Think About Ending", 'Did I Imagine You?', 'Who Will Save Your Soul', 'My Evil Is Strong', "Strugglin'", 'Out Of My Head'}
# 0.7916666666666666

# %%
# Get the indices of the most similar vectors
similar_indices_last = I[-5]  # Last array of indices

# Convert indices to user keys in the format user_000xxx incremented by 1
similar_user_keys_last = [f"user_{idx + 1:06d}" for idx in similar_indices_last]
similar_indices_last=similar_user_keys_last + similar_user_keys_last1

print("Most similar user keys (last array):")
print(similar_user_keys_last)

similar_user_tracks_all = [user_track_dict[key] for key in similar_user_keys_last]

# Flatten the list of lists into a single list and convert it to a set
all_tracks_set = set(track for tracks_list in similar_user_tracks_all for track in tracks_list)

# Extract values from user_track_dict for the key 'user_000992' and convert to set
user_000991_tracks_set = set(user_track_dict['user_000996'])

print("Set of tracks for user_000990:")
print(user_000991_tracks_set)

# Find elements present in user_000992_tracks_set but not in all_tracks_set
unique_tracks_user_000991 = user_000991_tracks_set - all_tracks_set

print("Unique tracks in user_000992_tracks_set:")
print(unique_tracks_user_000991)


print(1-len(unique_tracks_user_000991)/len(user_000991_tracks_set))
# Out:
# Most similar user keys (last array):
# ['user_000746', 'user_000862', 'user_000247', 'user_000485', 'user_000649', 'user_000027', 'user_000629', 'user_000182', 'user_000049', 'user_000245', 'user_000905', 'user_000078', 'user_000122', 'user_000516', 'user_000767', 'user_000916', 'user_000559', 'user_000156', 'user_000293', 'user_000576', 'user_000295', 'user_000810', 'user_000758', 'user_000799', 'user_000626', 'user_000291', 'user_000324', 'user_000448', 'user_000274', 'user_000409', 'user_000711', 'user_000710', 'user_000472', 'user_000227', 'user_000723', 'user_000476', 'user_000372', 'user_000023', 'user_000509', 'user_000597']
# Set of tracks for user_000990:
# {'Ghetto Youth', 'The Clock', 'In This World', 'Sail To The Moon', 'Counting Blue Cars', 'Street Spirit (Fade Out)', 'Walk The Line', 'Lump', 'Black Steel', 'Your Song', "Don'T Look Back In Anger", 'Nothing Left To Lose', 'Corpus Christi Carol', 'Karmacoma', 'Natural Blues', 'The Beautiful People', 'Girl', 'People Carrier', 'Length Of Love', 'Feel Good Inc. (Album Version)', 'Bullet With Butterfly Wings', 'Give It Away', 'Nobody', 'Asshole', 'Dance Me', 'Only You', 'Atoms For Peace', 'Morning Bell', 'Myxamatosis', 'Da Hoola (Soda-Pop Mix)', 'Mad About You', "Doin' Time (Uptown Dub)", 'The Passing Stars', 'Lovely Head', 'Unfinished Sympathy', 'Doll Parts', 'Life In Mono', 'Opener', 'Part Of The Process', 'All The Small Things', 'Protection (Feat. Tracey Thorn)', 'The Bends', 'Damn I Wish I Was Your Lover', 'Bullet Proof...I Wish I Was', 'Until The Morning', "L'Incertitude D'Heisenberg", 'Hemorrhage (In My Hands)', 'Losing My Religion', 'Your Song (Ewan Mcgregor)', "C'Mere", 'Love Can Damage Your Health', 'Hanging By A Moment', 'Excess', 'Cowboys', 'Ripcord', 'Makes Me Wanna Die', 'Go To Sleep', 'Skip Divided', 'Climbing Up The Walls  (Radioh', 'Where I End And You Begin', 'Light Blue Movers', 'Bad Things', 'Lebanese Blonde', 'I Might Be Wrong', 'Massive Attack - Safe From Harm', 'First Instant Last Report', 'Banquet', 'Forgive Them Father', '13 13 Radiohead - Black Star (Acoustic)', 'Wolf At The Door', 'Karma Coma', 'The Seed 2.0', '24 Hour Charleston', 'Lyrics Of Fury', 'A Time To Be So Small', 'Part Of The Queue', 'Message Personnel', 'Public Pervert', 'Ten Men', 'Sour Times', 'Smile', 'Honey', 'I Be The Prophet (With Drums)', 'Wonderwall (Acoustic)', 'Morning Sun', 'Daylight Robbery', "It'S Okay To Think About Ending", 'Half Day Closing', 'Fog', 'Caught By The River', 'Champagne Supernova', 'Colour Me', "Baba O'Remix", 'Subterranean Homesick Alien', 'What Your Soul Sings', 'Humming', 'Radiohead & Portishead - Blow Out', 'Glycerine', "The Word 'Hurricane'", 'So Real', 'Biscuit', 'The Eraser', 'Bullet Proof..I Wish I Was', 'Black Steel (Radio Edit)', 'Planet Telex', "Something'S Always Wrong", 'Ready To Go', 'Just', 'Treefingers', 'Black Swan', 'Undenied', 'Lighten Up', 'Radiohead - Coke Babies', 'Take A Picture', 'Smells Like Teen Spirit', 'Live With Me', 'How High', 'Seventeen Years', 'Angelica', 'Mezzanine', 'Hysteria', 'What Do I Have To Do?', 'Suffocated Love', 'Highschool Lover', 'Trishika', 'Over And Over', 'They', 'Far Behind', 'Who Can You Trust?', 'Kool Thing', 'Tricky Kid', 'Une Very Stylish Fille (Kenny Dope Mix)', 'Crawl', 'Fake Plastic Trees', 'Risingson (Underworld Mix)', 'All Mixed Up', 'Easy', 'Teardrop', 'Not Even Jail', 'Climbing Up The Walls', 'Banana Co', 'Rabbit In Your Headlights', 'Roads', 'Breathe', 'Girlfriend', 'I Wanna Feel The Chill', 'Transcendence', 'Nothing Even Matters', 'Acid Jazz And Trip Hop - Massi', 'And It Rained All Night', 'Just A Girl', "Brand New You'Re Retro", 'Feed Me', 'Sex Drive', 'Facts Are', 'Checkered Floor', 'Like Spinning Plates', 'Aftermath (Version 1)', 'Punchdrunk Lovesick Singalong', 'Trigger Hippie', 'Guitar Flute & String', 'Future Proof', 'Lonely Soul', 'Life In Mono (Propellerheads Sweat Band Mix)', 'Feel Good Inc.', 'Vent', 'Crazy In Love', 'Red Dust', 'Burn The Witch', 'Wash My Soul', 'The World I Know', 'In Winter Still', 'Exchange', 'Likufanele', 'Inertia Creeps', 'Sulk', 'Strict Machine', 'When It Hurts So Bad', 'New York', 'Idioteque', 'Evil', 'Mexicola', 'Next Exit', "Fallin'", 'Western Eyes', "Block Rockin' Beats", 'The Bends / Fake Plastic Trees', 'Analyse', 'Spinning', 'If You Could Only See', 'Pyramid Song', '6 Underground', 'Risingson', "Here'S To The Night", 'Give It Up', 'Christiansands', 'My Evil Is Strong', "Strugglin'", 'Antidote', 'Mysterons', 'Man Next Door', 'Paranoid Android', 'Grace', 'Salt Water Sound', 'Alpha Female', 'Moody', 'Last Flowers To The Hospital', 'Cherry', 'Sex And Candy', 'My Iron Lung', 'Love', 'Utopia', 'House Of The Rising Sun', ...
# Unique tracks in user_000992_tracks_set:
# {'Alpha Female', 'Hours From My Life', "Baba O'Remix", 'Radiohead & Portishead - Blow Out', "Something'S Always Wrong", "C' Mere", 'Radiohead - Sunday Bloody Sunday (U2 Cover Live)', 'People Carrier', 'Radiohead - Coke Babies', 'Feel Good Inc. (Album Version)', 'Desperately Wanting', 'B.O.B (Bombs Over Baghdad)', 'Asshole', 'What Do I Have To Do?', 'Born Slippy .Nuxx (Short)', 'In A State (Sasha Remix)', 'Dy-Na-Mi-Tee', 'Hey Pretty', 'Jesus Built My Hotrod', 'Interactive Booklet - The Eraser', 'Teenage Wasteland', 'Radiohead - Big Ideas', 'Une Very Stylish Fille (Kenny Dope Mix)', 'The Passing Stars', "It'S Been Done", 'Risingson (Underworld Mix)', 'Nobody Loves Me (Massive Attack Mix)', 'Opener', 'Protection (Feat. Tracey Thorn)', 'Radiohead - Coke Babies Copy', 'Poems', 'Bullet Proof...I Wish I Was', 'I Wanna Feel The Chill', '13 13 13 13 13 13 Radiohead - Black Star (Acoustic)', 'Your Song (Ewan Mcgregor)', 'Let The River Run', 'Depeche Mode - All I Ever Wanted', 'Acid Jazz And Trip Hop - Massi', 'Radiohead - Ladytron', 'Facts Are', 'Climbing Up The Walls  (Radioh', 'Scrappy Love', 'Aftermath (Version 1)', 'Edge Of The Ocean (Duotone Mix Edit)', 'I Want You Back (Single Version)', 'Massive Attack - Safe From Harm', 'First Instant Last Report', '13 13 Radiohead - Black Star (Acoustic)', 'Karma Coma', 'The Seed 2.0', 'Life In Mono (Propellerheads Sweat Band Mix)', '24 Hour Charleston', 'Super Bon Bon', 'Wash My Soul', 'Message Personnel', 'The World I Know', 'In Winter Still', 'Like A Military Coup', 'Velvet Divorce', 'Ten Men', 'Something In The Way She Moves (Beatles Cover)', 'Lightning Crashes', 'I Be The Prophet (With Drums)', 'Wonderwall (Acoustic)', 'The Bends / Fake Plastic Trees', 'Song Seven', 'Can I Kick It?', 'How I Made My Millions', 'Outkast - The Whole World(2)', "Here'S To The Night", "It'S Been Awhile", "It'S Okay To Think About Ending", 'Did I Imagine You?', 'Who Will Save Your Soul', 'Crimson And Clover', 'Angry Johnny', 'My Evil Is Strong'}
# 0.8217592592592593
